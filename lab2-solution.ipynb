# %% [markdown]
# # Lab №2

# %% [markdown]
# ## Выполнение

# %% [markdown]
# ### 0. Импортируем необходимые библиотеки

# %%
# !pip install roboticstoolbox-python
# Out:
# Requirement already satisfied: roboticstoolbox-python in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.26.4)
# Requirement already satisfied: spatialmath-python>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.1.14)
# Requirement already satisfied: spatialgeometry>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.1.0)
# Requirement already satisfied: pgraph-python in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (0.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.15.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (3.7.2)
# Requirement already satisfied: ansitable in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (0.11.4)
# Requirement already satisfied: swift-sim>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.1.0)
# Requirement already satisfied: rtb-data in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.0.1)
# Requirement already satisfied: progress in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (1.6)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from roboticstoolbox-python) (4.13.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.4->roboticstoolbox-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.4->roboticstoolbox-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.4->roboticstoolbox-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.4->roboticstoolbox-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.4->roboticstoolbox-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.4->roboticstoolbox-python) (2.4.1)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.11/dist-packages (from spatialmath-python>=1.1.5->roboticstoolbox-python) (4.2.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from swift-sim>=1.0.0->roboticstoolbox-python) (15.0.1)
# Requirement already satisfied: colored in /usr/local/lib/python3.11/dist-packages (from ansitable->roboticstoolbox-python) (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboticstoolbox-python) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->roboticstoolbox-python) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.4->roboticstoolbox-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.4->roboticstoolbox-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.4->roboticstoolbox-python) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17.4->roboticstoolbox-python) (2024.2.0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (2.6.12)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (6.0.2)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (20.31.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17.4->roboticstoolbox-python) (2024.2.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (3.18.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit->spatialmath-python>=1.1.5->roboticstoolbox-python) (4.3.8)

# %%
from math import pi
import numpy as np
import roboticstoolbox as rtb
import matplotlib.pyplot as plt
import spatialmath.base as sb

# %% [markdown]
# #### 1. Импортируем модель UR5

# %%
robot = rtb.models.DH.UR5()
print(robot)
# Out:
# DHRobot: UR5 (by Universal Robotics), 6 joints (RRRRRR), dynamics, standard DH parameters
# ┌─────┬─────────┬─────────┬────────┐
# │ θⱼ  │   dⱼ    │   aⱼ    │   ⍺ⱼ   │
# ├─────┼─────────┼─────────┼────────┤
# │  q1 │ 0.08946 │       0 │  90.0° │
# │  q2 │       0 │  -0.425 │   0.0° │
# │  q3 │       0 │ -0.3922 │   0.0° │
# │  q4 │  0.1091 │       0 │  90.0° │
# │  q5 │ 0.09465 │       0 │ -90.0° │
# │  q6 │  0.0823 │       0 │   0.0° │
# └─────┴─────────┴─────────┴────────┘
#
# ┌──┬──┐
# └──┴──┘
#
# ┌──────┬───────┬─────┬─────┬─────┬──────┬─────┐
# │ name │ q0    │ q1  │ q2  │ q3  │ q4   │ q5  │
# ├──────┼───────┼─────┼─────┼─────┼──────┼─────┤
# │   qr │  180° │  0° │  0° │  0° │  90° │  0° │
# │   qz │  0°   │  0° │  0° │  0° │  0°  │  0° │
# └──────┴───────┴─────┴─────┴─────┴──────┴─────┘

# %%
# Set restrictions on the joint variables
robot.links[0].qlim = [-2.792526803190927, 2.792526803190927]
robot.links[1].qlim = [-0.785398163397448, 3.926990816987241]
robot.links[2].qlim = [-3.926990816987241, 0.785398163397448]
robot.links[3].qlim = [-1.919862177193763, 2.967059728390360]
robot.links[4].qlim = [-1.745329251994330, 1.745329251994330]
robot.links[5].qlim = [-4.642575810304916, 4.642575810304916]

# %% [markdown]
# ### 2. Зададим начальное положение робота и построим его

# %%
q_start = [0, 0, 0, 0, 0, 0]
robot.plot(q_start)
plt.show()

# %% [markdown]
# ### 3. Решим прямую задачу кинематики

# %%
T_start = robot.fkine(q_start)
robot.plot(q_start)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   robot: Text(0.0, 0.0, 'UR5')

# %% [markdown]
# ### 6. Построим рабочую зону манипулятора (workspace)

# %% [markdown]
# Инициализируем переменные

# %%
n = 10  # Количество точек по каждой оси
i = 0  # Просто счетчик
move = [np.linspace(robot.links[i].qlim[0], robot.links[i].qlim[1], n) for i in range(4)]  # Записываем пределы перемещения для первых 4 звеньев
pose = np.zeros([3,n**4])  # Создаем пустой массив для записи данных

# %% [markdown]
# Рассчитываем рабочую зону

# %%
# Проходимся перебором по каждой точке
for q1 in move[0]:
    for q2 in move[1]:
        for q3 in move[2]:
            for q4 in move[3]:
                Tt = robot.fkine([q1,q2,q3,q4,0,0])  # Решаем ПЗК, меняя только первые 4 обобщенных координаты
                for j in range(3):
                    pose[j][i] = Tt.t[j]  # Сохраняем точку
                i += 1

# %% [markdown]
# Строим рабочую зону

# %%
plt.figure(figsize=(8,8), dpi=300)
ax = plt.axes(projection="3d")
ax.plot3D(pose[0], pose[1], pose[2], color='red', linewidth=0.15)
ax.scatter3D(pose[0], pose[1], pose[2], s=0.5, color='red')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(-1,1)
plt.show()

# %% [markdown]
# ### 7. Выберем конечную точку и проверим её (решим обратную задачу кинематики)

# %%
point = [-0.5,0.1,0.2]
T_end = sb.transl(point)
q_end = robot.ikine_GN(T_end).q  # Есть другие методы, помимо ikine_GN
robot.plot(q_end)
plt.show()

# %% [markdown]
# ### 8. Спланируем траекторию

# %% [markdown]
# Спланируем траекторию методом 'jtraj' для $N$ = 100 точек

# %%
N = 100
t_start = 0
t_stop = 5
t_shag = t_stop/N
time = np.arange(t_start, t_stop, t_shag)

# %% [markdown]
# Joint Trajectory (linear orbits in joint space)
#
# Create a transition trajectory from q_start to q_end in joint space.
#
# Use cubic interpolation for position, automatically calculate velocity and acceleration.

# %%
tr_jtraj = rtb.jtraj(q_start, q_end, time)

# %% [markdown]
# Спланируем ту же траекторию методом 'mtraj' с функцией 'trapezoidal'
#
# Use trapezoidal velocity profile: increase steadily, maintain steadily, then decrease steadily.
#
# Ideal for simulating motion with velocity and acceleration limits.

# %%
tr_trap = rtb.mtraj(rtb.trapezoidal, q_start, q_end, time)

# %% [markdown]
# Спланируем ту же траекторию методом 'mtraj' с функцией 'quintic'
#
# Use quintic polynomial interpolation — for extremely smooth motion: ensures zero position, velocity, and initial/final acceleration.
#
# Commonly used in robotics where vibration reduction is required, especially for precision arms.

# %%
tr_quin = rtb.mtraj(rtb.quintic, q_start, q_end, time)

# %% [markdown]
# ### 9. Построим графики

# %% [markdown]
# Построим графики положений для каждого звена

# %%
plt.figure(figsize=(10,5), dpi=300)  # Задаем размеры холста и плотность точек (четкость графика)
for g in range(1,7):
    plt.subplot(2,3,g)
    plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.2, hspace=0.25)  # Задаем интервалы между графиками, чтоб не перекрывали друг друга
    traektoriya_jtraj = [tr_jtraj.q[i][g-1] for i in range(len(tr_jtraj.q))]  # Извлекаем нужные данные
    traektoriya_trap = [tr_trap.q[i][g-1] for i in range(len(tr_trap.q))]  # Извлекаем нужные данные
    traektoriya_quin = [tr_quin.q[i][g-1] for i in range(len(tr_quin.q))]  # Извлекаем нужные данные
    plt.plot(time, traektoriya_jtraj, linestyle='-', linewidth=2, color=(1,0,0), label=r"jtraj")  # Рисуем линию
    plt.plot(time, traektoriya_trap, linestyle='-', linewidth=2, color=(0,1,0), label=r"lspb")  # Рисуем линию
    plt.plot(time, traektoriya_quin, linestyle='--', linewidth=2, color=(0,0,1), label=r"tpoly")  # Рисуем линию
    plt.title(r"Положение звена {}".format(g), fontsize=10)  # Название графика
    plt.ylabel(r"$q$  [$rad$]", fontsize=9)  # Подпись оси Y
    plt.xlabel(r"$t$  [$sec$]", fontsize=9)  # Подпись оси X
    plt.grid(True)  # Добавить сетку
    plt.legend()  # Отобразить легенду (покажет то, что написано в 'label')
    ax = plt.gca()  # gca = get current axis - чтобы редактировать конкретную фигуру
    ax.set_facecolor((1,1,1))  # Цвет фона на графике
    ax.set_xlim([t_start-0.1,t_stop+0.1])  # Пределы по оси X
plt.show()

# %% [markdown]
# Построим графики скоростей для каждого звена

# %%
plt.figure(figsize=(10,5), dpi=300)  # Задаем размеры холста и плотность точек (четкость графика)
for g in range(1,7):
    plt.subplot(2,3,g)
    plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.25, hspace=0.25)  # Задаем интервалы между графиками, чтоб не перекрывали друг друга
    traektoriya_jtraj = [tr_jtraj.qd[i][g-1] for i in range(len(tr_jtraj.qd))]  # Извлекаем нужные данные
    traektoriya_trap = [tr_trap.qd[i][g-1] for i in range(len(tr_trap.qd))]  # Извлекаем нужные данные
    traektoriya_quin = [tr_quin.qd[i][g-1] for i in range(len(tr_quin.qd))]  # Извлекаем нужные данные
    plt.plot(time, traektoriya_jtraj, linestyle='-', linewidth=2, color=(1,0,0), label=r"jtraj")  # Рисуем линию
    plt.plot(time, traektoriya_trap, linestyle='-', linewidth=2, color=(0,1,0), label=r"lspb")  # Рисуем линию
    plt.plot(time, traektoriya_quin, linestyle='--', linewidth=2, color=(0,0,1), label=r"tpoly")  # Рисуем линию
    plt.title(r"Скорость звена {}".format(g), fontsize=10)  # Название графика
    plt.ylabel(r"$dq/dt$  [$rad/sec$]", fontsize=9)  # Подпись оси Y
    plt.xlabel(r"$t$  [$sec$]", fontsize=9)  # Подпись оси X
    plt.grid(True)  # Добавить сетку
    plt.legend()  # Отобразить легенду (покажет то, что написано в 'label')
    ax = plt.gca()  # gca = get current axis - чтобы редактировать конкретную фигуру
    ax.set_facecolor((1,1,1))  # Цвет фона на графике
    ax.set_xlim([t_start-0.1,t_stop+0.1])  # Пределы по оси X
plt.show()

# %% [markdown]
# Построим графики ускорений для каждого звена

# %%
fig = plt.figure(figsize=(10,5), dpi=300)  # Задаем размеры холста и плотность точек (четкость графика)
for g in range(1,7):
    plt.subplot(2,3,g)
    plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.3, hspace=0.25)  # Задаем интервалы между графиками, чтоб не перекрывали друг друга
    traektoriya_jtraj = [tr_jtraj.qdd[i][g-1] for i in range(len(tr_jtraj.qdd))]  # Извлекаем нужные данные
    traektoriya_trap = [tr_trap.qdd[i][g-1] for i in range(len(tr_trap.qdd))]  # Извлекаем нужные данные
    traektoriya_quin = [tr_quin.qdd[i][g-1] for i in range(len(tr_quin.qdd))]  # Извлекаем нужные данные
    plt.plot(time, traektoriya_jtraj, linestyle='-', linewidth=2, color=(1,0,0), label=r"jtraj")  # Рисуем линию
    plt.plot(time, traektoriya_trap, linestyle='-', linewidth=2, color=(0,1,0), label=r"lspb")  # Рисуем линию
    plt.plot(time, traektoriya_quin, linestyle='--', linewidth=2, color=(0,0,1), label=r"tpoly")  # Рисуем линию
    plt.title(r"Ускорение звена {}".format(g), fontsize=10)  # Название графика
    plt.ylabel(r"${d^2}q/d{t^2}$  [$rad/{sec}^2$]", fontsize=9)  # Подпись оси Y
    plt.xlabel(r"$t$  [$sec$]", fontsize=9)  # Подпись оси X
    plt.grid(True)  # Добавить сетку
    plt.legend()  # Отобразить легенду (покажет то, что написано в 'label')
    ax = plt.gca()  # gca = get current axis - чтобы редактировать конкретную фигуру
    ax.set_facecolor((1,1,1))  # Цвет фона на графике
    ax.set_xlim([t_start-0.1,t_stop+0.1])  # Пределы по оси X
plt.show()

# %% [raw]
# Conclusion:
#
# 1. Solve the forward kinematics
# - robot.fkine() returns a homogeneous transformation matrix T_start that describes the pose (position and orientation) of the end-effector in 3D space
#
# 2. Visualize workspace of manipulator
# - In this code we scan the workspace of the first four joints of the robot, uses forward kinematics (fkine) to calculate the corresponding end-effector position, and saves the result.
#
# 3. Solve the inverse kinematics
# - Choose a target point in space, converts it to a transformation matrix, solves for the joint configuration that reaches that point using inverse kinematics, and then visualizes the resulting pose of the robot.
#
# 4. Trajectory planning
# - jtraj: Use cubic interpolation for position, automatically calculate velocity and acceleration
# - mtraj + trapezoidal: Use trapezoidal velocity profile: increase steadily, maintain steadily, then decrease steadily.
# - mtraj + quintic: Use quintic polynomial interpolation — for extremely smooth motion: ensures zero position, velocity, and initial/final acceleration.
